# %% [markdown]
# # Time series outlier detection with Spectral Residuals on synthetic data
#
# ## Method
#
# The Spectral Residual outlier detector is based on the paper [Time-Series Anomaly Detection Service at Microsoft](https://arxiv.org/abs/1906.03821) and is suitable for unsupervised online anomaly detection in univariate time series data. The algorithm first computes the [Fourier Transform](https://en.wikipedia.org/wiki/Fourier_transform) of the original data. Then it computes the *spectral residual* of the log amplitude of the transformed signal before applying the Inverse Fourier Transform to map the sequence back from the frequency to the time domain. This sequence is called the *saliency map*. The anomaly score is then computed as the relative difference between the saliency map values and their moving averages. If this score is above a threshold, the value at a specific timestep is flagged as an outlier. For more details, please check out the [paper](https://arxiv.org/abs/1906.03821).
#
# ## Dataset
#
# We test the outlier detector on a synthetic dataset generated with the [TimeSynth](https://github.com/TimeSynth/TimeSynth) package. It allows you to generate a wide range of time series (e.g. pseudo-periodic, autoregressive or Gaussian Process generated signals) and noise types (white or red noise). It can be installed as follows:

# %%
# !pip install git+https://github.com/TimeSynth/TimeSynth.git
# Out:
# Collecting git+https://github.com/TimeSynth/TimeSynth.git
#   Cloning https://github.com/TimeSynth/TimeSynth.git to /tmp/pip-req-build-bdlmwtbx
#   Running command git clone -q https://github.com/TimeSynth/TimeSynth.git /tmp/pip-req-build-bdlmwtbx
#   Resolved https://github.com/TimeSynth/TimeSynth.git to commit e50cdb9015d415adf46a4eae161a087c5c378564
# Requirement already satisfied: numpy in /home/robert/miniconda3/envs/detect/lib/python3.8/site-packages (from timesynth==0.2.4) (1.19.5)
# Requirement already satisfied: scipy in /home/robert/miniconda3/envs/detect/lib/python3.8/site-packages (from timesynth==0.2.4) (1.7.2)
# Requirement already satisfied: sympy in /home/robert/miniconda3/envs/detect/lib/python3.8/site-packages (from timesynth==0.2.4) (1.9)
# Requirement already satisfied: symengine>=0.4 in /home/robert/miniconda3/envs/detect/lib/python3.8/site-packages (from timesynth==0.2.4) (0.8.1)
# Requirement already satisfied: jitcdde==1.4 in /home/robert/miniconda3/envs/detect/lib/python3.8/site-packages (from timesynth==0.2.4) (1.4.0)
# Requirement already satisfied: jitcxde_common==1.4.1 in /home/robert/miniconda3/envs/detect/lib/python3.8/site-packages (from timesynth==0.2.4) (1.4.1)
# Requirement already satisfied: jinja2 in /home/robert/miniconda3/envs/detect/lib/python3.8/site-packages (from jitcxde_common==1.4.1->timesynth==0.2.4) (3.0.3)
# Requirement already satisfied: setuptools in /home/robert/miniconda3/envs/detect/lib/python3.8/site-packages (from jitcxde_common==1.4.1->timesynth==0.2.4) (58.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/robert/miniconda3/envs/detect/lib/python3.8/site-packages (from jinja2->jitcxde_common==1.4.1->timesynth==0.2.4) (2.0.1)
# Requirement already satisfied: mpmath>=0.19 in /home/robert/miniconda3/envs/detect/lib/python3.8/site-packages (from sympy->timesynth==0.2.4) (1.2.1)

# %% [markdown]
# Additionally, this notebook requires the `seaborn` package for visualization which can be installed via `pip`:

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in /home/robert/miniconda3/envs/detect/lib/python3.8/site-packages (0.11.2)
# Requirement already satisfied: matplotlib>=2.2 in /home/robert/miniconda3/envs/detect/lib/python3.8/site-packages (from seaborn) (3.5.0)
# Requirement already satisfied: scipy>=1.0 in /home/robert/miniconda3/envs/detect/lib/python3.8/site-packages (from seaborn) (1.7.2)
# Requirement already satisfied: pandas>=0.23 in /home/robert/miniconda3/envs/detect/lib/python3.8/site-packages (from seaborn) (1.3.4)
# Requirement already satisfied: numpy>=1.15 in /home/robert/miniconda3/envs/detect/lib/python3.8/site-packages (from seaborn) (1.19.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/robert/miniconda3/envs/detect/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (1.3.2)
# Requirement already satisfied: setuptools-scm>=4 in /home/robert/miniconda3/envs/detect/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (6.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in /home/robert/miniconda3/envs/detect/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (4.28.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/robert/miniconda3/envs/detect/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (3.0.6)
# Requirement already satisfied: packaging>=20.0 in /home/robert/miniconda3/envs/detect/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/robert/miniconda3/envs/detect/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /home/robert/miniconda3/envs/detect/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (8.4.0)
# Requirement already satisfied: cycler>=0.10 in /home/robert/miniconda3/envs/detect/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: pytz>=2017.3 in /home/robert/miniconda3/envs/detect/lib/python3.8/site-packages (from pandas>=0.23->seaborn) (2021.3)
# Requirement already satisfied: six>=1.5 in /home/robert/miniconda3/envs/detect/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.15.0)
# Requirement already satisfied: setuptools in /home/robert/miniconda3/envs/detect/lib/python3.8/site-packages (from setuptools-scm>=4->matplotlib>=2.2->seaborn) (58.0.4)
# Requirement already satisfied: tomli>=1.0.0 in /home/robert/miniconda3/envs/detect/lib/python3.8/site-packages (from setuptools-scm>=4->matplotlib>=2.2->seaborn) (1.2.2)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.metrics import accuracy_score, confusion_matrix, f1_score, recall_score
import timesynth as ts

from alibi_detect.od import SpectralResidual
from alibi_detect.utils.perturbation import inject_outlier_ts
from alibi_detect.utils.saving import save_detector, load_detector
from alibi_detect.utils.visualize import plot_instance_score, plot_feature_outlier_ts

# %% [markdown]
# ## Create univariate time series
#
# Define number of sampled points and the type of simulated time series. We use [TimeSynth](https://github.com/TimeSynth/TimeSynth) to generate a sinusoidal signal with Gaussian noise.

# %%
n_points = 1000

# %%
# timestamps
time_sampler = ts.TimeSampler(stop_time=n_points // 4)
time_samples = time_sampler.sample_regular_time(num_points=n_points)

# harmonic time series with Gaussian noise
sinusoid = ts.signals.Sinusoidal(frequency=0.25, ftype=np.cos)
white_noise = ts.noise.GaussianNoise(std=0.1)
ts_harm = ts.TimeSeries(signal_generator=sinusoid, noise_generator=white_noise)
samples, signals, errors = ts_harm.sample(time_samples)

# add some offest
offset = 100
samples += offset
signals += offset

X = samples.reshape(-1, 1).astype(np.float32)
print(X.shape)
# Out:
# (1000, 1)

# %% [markdown]
# We can inject noise in the time series via `inject_outlier_ts`. The noise can be regulated via the percentage of outliers (`perc_outlier`), the strength of the perturbation (`n_std`) and the minimum size of the noise perturbation (`min_std`):

# %%
data = inject_outlier_ts(X, perc_outlier=10, perc_window=10, n_std=2., min_std=1.)
X_outlier, y_outlier, labels = data.data, data.target.astype(int), data.target_names
print(X_outlier.shape, y_outlier.shape)
# Out:
# (1000, 1) (1000,)

# %% [markdown]
# Visualize part of the original and perturbed time series:

# %%
n_plot = 200

# %%
plt.plot(time_samples[:n_plot], X[:n_plot], marker='o', markersize=4, label='sample')
plt.plot(time_samples[:n_plot], signals[:n_plot], marker='*', markersize=4, label='signal')
plt.plot(time_samples[:n_plot], errors[:n_plot], marker='.', markersize=4, label='noise')
plt.xlabel('Time')
plt.ylabel('Magnitude')
plt.title('Original sinusoid with noise')
plt.legend()
plt.show();

# %% [markdown]
# Perturbed data:

# %%
plt.plot(time_samples[:n_plot], X[:n_plot], marker='o', markersize=4, label='original')
plt.plot(time_samples[:n_plot], X_outlier[:n_plot], marker='*', markersize=4, label='perturbed')
plt.xlabel('Time')
plt.ylabel('Magnitude')
plt.title('Original vs. perturbed data')
plt.legend()
plt.show();

# %% [markdown]
# ## Define Spectral Residual outlier detector

# %%
od = SpectralResidual(
    threshold=None,  # threshold for outlier score
    window_amp=20,   # window for the average log amplitude
    window_local=20, # window for the average saliency map
    n_est_points=20, # nb of estimated points padded to the end of the sequence
    use_old=True
)
# Out:
# No threshold level set. Need to infer threshold using `infer_threshold`.

# %% [markdown]
# The warning tells us that we need to set the outlier threshold. This can be done with the `infer_threshold` method. We need to pass a batch of instances and specify what percentage of those we consider to be normal via `threshold_perc`. Let's assume we have some data which we know contains around 10% outliers:

# %%
X_threshold = X_outlier[:10000, :]

# %% [markdown]
# Let's infer the threshold:

# %%
od.infer_threshold(X_threshold, time_samples[:10000], threshold_perc=90)
print('New threshold: {:.4f}'.format(od.threshold))
# Out:
# New threshold: 0.0035

# %% [markdown]
# Let's save the outlier detector with the updated threshold:

# %%
filepath = 'my_path'
save_detector(od, filepath)

# %% [markdown]
# We can load the same detector via `load_detector`:

# %%
od = load_detector(filepath)

# %% [markdown]
# ## Detect outliers

# %% [markdown]
# Predict outliers:

# %%
od_preds = od.predict(X_outlier, time_samples, return_instance_score=True)

# %% [markdown]
# ## Display results

# %% [markdown]
# F1 score, accuracy, recall and confusion matrix:

# %%
y_pred = od_preds['data']['is_outlier']
f1 = f1_score(y_outlier, y_pred)
acc = accuracy_score(y_outlier, y_pred)
rec = recall_score(y_outlier, y_pred)
print('F1 score: {} -- Accuracy: {} -- Recall: {}'.format(f1, acc, rec))
cm = confusion_matrix(y_outlier, y_pred)
df_cm = pd.DataFrame(cm, index=labels, columns=labels)
sns.heatmap(df_cm, annot=True, cbar=True, linewidths=.5)
plt.show()
# Out:
# F1 score: 0.37759336099585067 -- Accuracy: 0.7 -- Recall: 0.91

# %% [markdown]
# Plot the outlier scores of the time series vs. the outlier threshold. :

# %%
plot_instance_score(od_preds, y_outlier, labels, od.threshold)

# %% [markdown]
# Let's zoom in on a smaller time scale to have a clear picture:

# %%
plot_feature_outlier_ts(od_preds, 
                        X_outlier, 
                        od.threshold,
                        window=(100, 150),
                        t=time_samples,
                        X_orig=X)
